# %%
# Import the modules
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.metrics import balanced_accuracy_score, confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler

# %%
# Read the CSV file from the Resources folder into a Pandas DataFrame

data_df = pd.read_csv("Resources/diabetes_prediction_dataset.csv")

# Review the DataFrame

data_df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# 1              6.6                   80         0
# 2              5.7                  158         0
# 3              5.0                  155         0
# 4              4.8                  155         0
# ...            ...                  ...       ...
# 99995          6.2                   90         0
# 99996          6.5                  100         0
# 99997          5.7                  155         0
# 99998          4.0                  100         0
# 99999          6.6                   90         0
#
# [100000 rows x 9 columns]

# %%
data_df.describe()
# Out:
#                  age  hypertension  heart_disease            bmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# std         1.070672            40.708136       0.278883
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# 50%         5.800000           140.000000       0.000000
# 75%         6.200000           159.000000       0.000000
# max         9.000000           300.000000       1.000000

# %%
diabetes_data_df = data_df.loc[data_df["age"] >= 3].reset_index().drop(columns="index")

diabetes_data_df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 96708  Female  36.0             0              0         No Info  24.60
# 96709  Female  80.0             0              0         No Info  27.32
# 96710    Male  66.0             0              0          former  27.83
# 96711  Female  24.0             0              0           never  35.42
# 96712  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# 1              6.6                   80         0
# 2              5.7                  158         0
# 3              5.0                  155         0
# 4              4.8                  155         0
# ...            ...                  ...       ...
# 96708          4.8                  145         0
# 96709          6.2                   90         0
# 96710          5.7                  155         0
# 96711          4.0                  100         0
# 96712          6.6                   90         0
#
# [96713 rows x 9 columns]

# %%
diabetes_data_df["smoking_history"].value_counts()
# Out:
# never          34824
# No Info        32840
# former          9352
# current         9276
# not current     6417
# ever            4004
# Name: smoking_history, dtype: int64

# %%
diabetes_data_df["smoking_history"] = diabetes_data_df["smoking_history"].replace('not current', 'former')
diabetes_data_df["smoking_history"] = diabetes_data_df["smoking_history"].replace('ever', 'occasional')
diabetes_data_df["smoking_history"].value_counts()
# Out:
# never         34824
# No Info       32840
# former        15769
# current        9276
# occasional     4004
# Name: smoking_history, dtype: int64

# %%
diabetes_data_df = diabetes_data_df[diabetes_data_df["gender"] != "Other"]
diabetes_data_df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 96708  Female  36.0             0              0         No Info  24.60
# 96709  Female  80.0             0              0         No Info  27.32
# 96710    Male  66.0             0              0          former  27.83
# 96711  Female  24.0             0              0           never  35.42
# 96712  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# 1              6.6                   80         0
# 2              5.7                  158         0
# 3              5.0                  155         0
# 4              4.8                  155         0
# ...            ...                  ...       ...
# 96708          4.8                  145         0
# 96709          6.2                   90         0
# 96710          5.7                  155         0
# 96711          4.0                  100         0
# 96712          6.6                   90         0
#
# [96695 rows x 9 columns]

# %%
diabetes_data_df.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
diabetes_data_df["gender"].value_counts()
# Out:
# Female    56951
# Male      39744
# Name: gender, dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder

# # Initialize the OneHotEncoder
# enc = OneHotEncoder(handle_unknown='ignore')

# # Fit and transform the 'Status' column
# X = enc.fit_transform(diabetes_data_df[['smoking_history']])

# %%
# The result is a sparse matrix, you can convert it to a DataFrame if needed
# result_df = pd.DataFrame(X.toarray(), columns=enc.get_feature_names_out(['smoking_history']))
# result_df

# %%
diabetes_data_df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 96708  Female  36.0             0              0         No Info  24.60
# 96709  Female  80.0             0              0         No Info  27.32
# 96710    Male  66.0             0              0          former  27.83
# 96711  Female  24.0             0              0           never  35.42
# 96712  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# 1              6.6                   80         0
# 2              5.7                  158         0
# 3              5.0                  155         0
# 4              4.8                  155         0
# ...            ...                  ...       ...
# 96708          4.8                  145         0
# 96709          6.2                   90         0
# 96710          5.7                  155         0
# 96711          4.0                  100         0
# 96712          6.6                   90         0
#
# [96695 rows x 9 columns]

# %%
# # Concatenate the result with the original DataFrame, dropping the original 'Status' column
# diabetes_data_encoded_df = pd.concat([diabetes_data_df.drop(columns=['smoking_history']), result_df], axis=1)

# # Print the updated DataFrame
# diabetes_data_encoded_df

# %%
# Specify the column(s) you want to one-hot encode
categorical_columns = ["gender", "smoking_history"]

# Use pd.get_dummies to one-hot encode the specified columns
diabetes_data_encoded_df = pd.get_dummies(diabetes_data_df, columns=categorical_columns)
diabetes_data_encoded_df
# Out:
#         age  hypertension  heart_disease    bmi  HbA1c_level  \
# 0      80.0             0              1  25.19          6.6
# 1      54.0             0              0  27.32          6.6
# 2      28.0             0              0  27.32          5.7
# 3      36.0             0              0  23.45          5.0
# 4      76.0             1              1  20.14          4.8
# ...     ...           ...            ...    ...          ...
# 96708  36.0             0              0  24.60          4.8
# 96709  80.0             0              0  27.32          6.2
# 96710  66.0             0              0  27.83          5.7
# 96711  24.0             0              0  35.42          4.0
# 96712  57.0             0              0  22.43          6.6
#
#        blood_glucose_level  diabetes  gender_Female  gender_Male  \
# 0                      140         0              1            0
# 1                       80         0              1            0
# 2                      158         0              0            1
# 3                      155         0              1            0
# 4                      155         0              0            1
# ...                    ...       ...            ...          ...
# 96708                  145         0              1            0
# 96709                   90         0              1            0
# 96710                  155         0              0            1
# 96711                  100         0              1            0
# 96712                   90         0              1            0
#
#        smoking_history_No Info  smoking_history_current  \
# 0                            0                        0
# 1                            1                        0
# 2                            0                        0
# 3                            0                        1
# 4                            0                        1
# ...                        ...                      ...
# 96708                        1                        0
# 96709                        1                        0
# 96710                        0                        0
# 96711                        0                        0
# 96712                        0                        1
#
#        smoking_history_former  smoking_history_never  \
# 0                           0                      1
# 1                           0                      0
# 2                           0                      1
# 3                           0                      0
# 4                           0                      0
# ...                       ...                    ...
# 96708                       0                      0
# 96709                       0                      0
# 96710                       1                      0
# 96711                       0                      1
# 96712                       0                      0
#
#        smoking_history_occasional
# 0                               0
# 1                               0
# 2                               0
# 3                               0
# 4                               0
# ...                           ...
# 96708                           0
# 96709                           0
# 96710                           0
# 96711                           0
# 96712                           0
#
# [96695 rows x 14 columns]

# %%
# diabetes_data_encoded_df.to_csv('diabetes.csv', index=False)

# %%
# Seperate the features, X,  from the target variable, y
y = diabetes_data_encoded_df['diabetes']
X = diabetes_data_encoded_df.drop(columns='diabetes')

# %%
# Review the y variable Series
y.head(3)
# Out:
# 0    0
# 1    0
# 2    0
# Name: diabetes, dtype: int64

# %%
# Review the X variable DataFrame
X.head()
# Out:
#     age  hypertension  heart_disease    bmi  HbA1c_level  blood_glucose_level  \
# 0  80.0             0              1  25.19          6.6                  140
# 1  54.0             0              0  27.32          6.6                   80
# 2  28.0             0              0  27.32          5.7                  158
# 3  36.0             0              0  23.45          5.0                  155
# 4  76.0             1              1  20.14          4.8                  155
#
#    gender_Female  gender_Male  smoking_history_No Info  \
# 0              1            0                        0
# 1              1            0                        1
# 2              0            1                        0
# 3              1            0                        0
# 4              0            1                        0
#
#    smoking_history_current  smoking_history_former  smoking_history_never  \
# 0                        0                       0                      1
# 1                        0                       0                      0
# 2                        0                       0                      1
# 3                        1                       0                      0
# 4                        1                       0                      0
#
#    smoking_history_occasional
# 0                           0
# 1                           0
# 2                           0
# 3                           0
# 4                           0

# %%
# Check the balance of our target values
y.value_counts()
# Out:
# 0    88195
# 1     8500
# Name: diabetes, dtype: int64

# %%
# Import the train_test_learn module
from sklearn.model_selection import train_test_split

# Split the data using train_test_split
# Assign a random_state of 1 to the function
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Import the LogisticRegression module from SKLearn
from sklearn.linear_model import LogisticRegression

# Instantiate the Logistic Regression model
# Assign a random_state parameter of 1 to the model
classifier = LogisticRegression(solver='lbfgs', random_state=1)

# Fit the model using training data
classifier.fit(X_train, y_train)
# Out:
# c:\Users\iahme\anaconda3\envs\dev\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=1)

# %%
# Make a prediction using the testing data
predictions = classifier.predict(X_test)
pd.DataFrame({"Prediction": predictions, "Actual": y_test})
# Out:
#        Prediction  Actual
# 45593           0       0
# 52405           0       0
# 28793           0       0
# 39868           0       0
# 62951           0       0
# ...           ...     ...
# 79507           0       0
# 95439           0       0
# 31463           0       0
# 46757           0       0
# 51100           0       0
#
# [24174 rows x 2 columns]

# %%
# Print the balanced_accuracy score of the model
from sklearn.metrics import accuracy_score
# Display the accuracy score for the test dataset.
accuracy_score(y_test, predictions)
# Out:
# 0.9571440390502193

# %%
# Generate a confusion matrix for the model
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, predictions)
# Out:
# array([[21790,   232],
#        [  804,  1348]], dtype=int64)

# %%
# Print the classification report for the model
from sklearn.metrics import classification_report
target_names = ["No Diabetes", "Diabetes"]
print(classification_report(y_test, predictions, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#  No Diabetes       0.96      0.99      0.98     22022
#     Diabetes       0.85      0.63      0.72      2152
#
#     accuracy                           0.96     24174
#    macro avg       0.91      0.81      0.85     24174
# weighted avg       0.95      0.96      0.95     24174

# %%
# from sklearn.preprocessing import StandardScaler

# # Instantiate a StandardScaler instance
# scaler = StandardScaler()

# # Fit the training data to the standard scaler
# X_scaler = scaler.fit(X_train)

# # Transform the training data using the scaler
# X_train_scaled = X_scaler.transform(X_train)

# # Transform the testing data using the scaler
# X_test_scaled = X_scaler.transform(X_test)

# %%
# Import the RandomOverSampler module form imbalanced-learn
from imblearn.over_sampling import RandomOverSampler
# Instantiate the random oversampler model
# Assign a random_state parameter of 1 to the model
over_sampler = RandomOverSampler(random_state=1)
# Fit the original training data to the random_oversampler model
X_train_resampled, y_train_resampled = over_sampler.fit_resample(X_train, y_train)

# %%
# Count the distinct values of the resampled labels data
y_train_resampled.value_counts()
# Out:
# 0    66173
# 1    66173
# Name: diabetes, dtype: int64

# %%
# Instantiate the Logistic Regression model
# Assign a random_state parameter of 1 to the model
classifier = LogisticRegression(solver='lbfgs', random_state=1)

# Fit the model using the resampled training data
classifier.fit(X_train_resampled, y_train_resampled)
# Make a prediction using the testing data
predictions = classifier.predict(X_test)
pd.DataFrame({"Prediction": predictions, "Actual": y_test})
# Out:
# c:\Users\iahme\anaconda3\envs\dev\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#        Prediction  Actual
# 45593           0       0
# 52405           0       0
# 28793           0       0
# 39868           0       0
# 62951           0       0
# ...           ...     ...
# 79507           0       0
# 95439           0       0
# 31463           0       0
# 46757           1       0
# 51100           0       0
#
# [24174 rows x 2 columns]

# %%
# Print the balanced_accuracy score of the model 
# Display the accuracy score for the test dataset.
accuracy_score(y_test, predictions)
# Out:
# 0.8857863820633739

# %%
# Generate a confusion matrix for the model
confusion_matrix(y_test, predictions)
# Out:
# array([[19511,  2511],
#        [  250,  1902]], dtype=int64)

# %%
# Print the classification report for the model
target_names = ["no diabetes", "diabetes"]
print(classification_report(y_test, predictions, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#  no diabetes       0.99      0.89      0.93     22022
#     diabetes       0.43      0.88      0.58      2152
#
#     accuracy                           0.89     24174
#    macro avg       0.71      0.88      0.76     24174
# weighted avg       0.94      0.89      0.90     24174

# %%
# Split our preprocessed data into our features and target arrays
y = diabetes_data_encoded_df['diabetes'].values
X = diabetes_data_encoded_df.drop(columns=['diabetes']).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
import tensorflow as tf
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  80
hidden_nodes_layer2 = 30

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim = number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                1120
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 3581 (13.99 KB)
# Trainable params: 3581 (13.99 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 2267/2267 [==============================] - 4s 1ms/step - loss: 0.1288 - accuracy: 0.9549
# Epoch 2/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.1080 - accuracy: 0.9631
# Epoch 3/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0964 - accuracy: 0.9675
# Epoch 4/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0908 - accuracy: 0.9690
# Epoch 5/100
# 2267/2267 [==============================] - 3s 2ms/step - loss: 0.0883 - accuracy: 0.9697
# Epoch 6/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0875 - accuracy: 0.9697
# Epoch 7/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0864 - accuracy: 0.9703
# Epoch 8/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0859 - accuracy: 0.9705
# Epoch 9/100
# 2267/2267 [==============================] - 3s 2ms/step - loss: 0.0853 - accuracy: 0.9707
# Epoch 10/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0853 - accuracy: 0.9707
# Epoch 11/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0851 - accuracy: 0.9706
# Epoch 12/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0849 - accuracy: 0.9706
# Epoch 13/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0846 - accuracy: 0.9708
# Epoch 14/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0842 - accuracy: 0.9708
# Epoch 15/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0845 - accuracy: 0.9708
# Epoch 16/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0840 - accuracy: 0.9707
# Epoch 17/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0836 - accuracy: 0.9713
# Epoch 18/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0839 - accuracy: 0.9711
# Epoch 19/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0837 - accuracy: 0.9713
# Epoch 20/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0836 - accuracy: 0.9708
# Epoch 21/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0835 - accuracy: 0.9713
# Epoch 22/100
# 2267/2267 [==============================] - 2s 1ms/step - loss: 0.0833 - accuracy: 0.9710
# Epoch 23/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0832 - accuracy: 0.9712
# Epoch 24/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0832 - accuracy: 0.9714
# Epoch 25/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0831 - accuracy: 0.9712
# Epoch 26/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0827 - accuracy: 0.9714
# Epoch 27/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0827 - accuracy: 0.9717
# Epoch 28/100
# 2267/2267 [==============================] - 4s 2ms/step - loss: 0.0828 - accuracy: 0.9715
# Epoch 29/100
# 2267/2267 [==============================] - 4s 2ms/step - loss: 0.0825 - accuracy: 0.9713
# Epoch 30/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0826 - accuracy: 0.9712
# Epoch 31/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0822 - accuracy: 0.9713
# Epoch 32/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0821 - accuracy: 0.9715
# Epoch 33/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0820 - accuracy: 0.9717
# Epoch 34/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0820 - accuracy: 0.9716
# Epoch 35/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0819 - accuracy: 0.9713
# Epoch 36/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0816 - accuracy: 0.9715
# Epoch 37/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0818 - accuracy: 0.9716
# Epoch 38/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0814 - accuracy: 0.9718
# Epoch 39/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0815 - accuracy: 0.9716
# Epoch 40/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0811 - accuracy: 0.9719
# Epoch 41/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0812 - accuracy: 0.9720
# Epoch 42/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0812 - accuracy: 0.9718
# Epoch 43/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0811 - accuracy: 0.9720
# Epoch 44/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0812 - accuracy: 0.9718
# Epoch 45/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0807 - accuracy: 0.9716
# Epoch 46/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0808 - accuracy: 0.9718
# Epoch 47/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0806 - accuracy: 0.9720
# Epoch 48/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0803 - accuracy: 0.9721
# Epoch 49/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0806 - accuracy: 0.9719
# Epoch 50/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0805 - accuracy: 0.9719
# Epoch 51/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0801 - accuracy: 0.9721
# Epoch 52/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0803 - accuracy: 0.9721
# Epoch 53/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0801 - accuracy: 0.9721
# Epoch 54/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0801 - accuracy: 0.9720
# Epoch 55/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0801 - accuracy: 0.9719
# Epoch 56/100
# 2267/2267 [==============================] - 2s 1ms/step - loss: 0.0802 - accuracy: 0.9720
# Epoch 57/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0796 - accuracy: 0.9723
# Epoch 58/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0797 - accuracy: 0.9722
# Epoch 59/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0793 - accuracy: 0.9723
# Epoch 60/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0794 - accuracy: 0.9722
# Epoch 61/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0793 - accuracy: 0.9720
# Epoch 62/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0794 - accuracy: 0.9724
# Epoch 63/100
# 2267/2267 [==============================] - 2s 1ms/step - loss: 0.0792 - accuracy: 0.9722
# Epoch 64/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0791 - accuracy: 0.9723
# Epoch 65/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0788 - accuracy: 0.9723
# Epoch 66/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0791 - accuracy: 0.9722
# Epoch 67/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0790 - accuracy: 0.9723
# Epoch 68/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0788 - accuracy: 0.9725
# Epoch 69/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0788 - accuracy: 0.9724
# Epoch 70/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0786 - accuracy: 0.9722
# Epoch 71/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0788 - accuracy: 0.9725
# Epoch 72/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0784 - accuracy: 0.9724
# Epoch 73/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0783 - accuracy: 0.9725
# Epoch 74/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0780 - accuracy: 0.9725
# Epoch 75/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0782 - accuracy: 0.9726
# Epoch 76/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0779 - accuracy: 0.9726
# Epoch 77/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0779 - accuracy: 0.9726
# Epoch 78/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0779 - accuracy: 0.9726
# Epoch 79/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0777 - accuracy: 0.9727
# Epoch 80/100
# 2267/2267 [==============================] - 2s 1ms/step - loss: 0.0776 - accuracy: 0.9725
# Epoch 81/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0778 - accuracy: 0.9727
# Epoch 82/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0778 - accuracy: 0.9727
# Epoch 83/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0775 - accuracy: 0.9727
# Epoch 84/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0773 - accuracy: 0.9728
# Epoch 85/100
# 2267/2267 [==============================] - 2s 1ms/step - loss: 0.0772 - accuracy: 0.9729
# Epoch 86/100
# 2267/2267 [==============================] - 2s 1ms/step - loss: 0.0772 - accuracy: 0.9728
# Epoch 87/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0771 - accuracy: 0.9730
# Epoch 88/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0770 - accuracy: 0.9731
# Epoch 89/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0771 - accuracy: 0.9730
# Epoch 90/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0768 - accuracy: 0.9730
# Epoch 91/100
# 2267/2267 [==============================] - 2s 1ms/step - loss: 0.0769 - accuracy: 0.9727
# Epoch 92/100
# 2267/2267 [==============================] - 2s 1ms/step - loss: 0.0770 - accuracy: 0.9730
# Epoch 93/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0766 - accuracy: 0.9728
# Epoch 94/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0767 - accuracy: 0.9731
# Epoch 95/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0762 - accuracy: 0.9731
# Epoch 96/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0765 - accuracy: 0.9729
# Epoch 97/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0765 - accuracy: 0.9731
# Epoch 98/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0761 - accuracy: 0.9732
# Epoch 99/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0763 - accuracy: 0.9729
# Epoch 100/100
# 2267/2267 [==============================] - 3s 1ms/step - loss: 0.0761 - accuracy: 0.9729

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 756/756 - 1s - loss: 0.0931 - accuracy: 0.9695 - 802ms/epoch - 1ms/step
# Loss: 0.09308144450187683, Accuracy: 0.9695127010345459

# %%
# # Export our model to HDF5 file
# nn.save("DiabetesNN1.h5")

# %%
diabetes_data_encoded_df = diabetes_data_encoded_df.rename(columns={'smoking_history_No Info': 'smoking_history_No_Info'})
diabetes_data_encoded_df
# Out:
#         age  hypertension  heart_disease    bmi  HbA1c_level  \
# 0      80.0             0              1  25.19          6.6
# 1      54.0             0              0  27.32          6.6
# 2      28.0             0              0  27.32          5.7
# 3      36.0             0              0  23.45          5.0
# 4      76.0             1              1  20.14          4.8
# ...     ...           ...            ...    ...          ...
# 96708  36.0             0              0  24.60          4.8
# 96709  80.0             0              0  27.32          6.2
# 96710  66.0             0              0  27.83          5.7
# 96711  24.0             0              0  35.42          4.0
# 96712  57.0             0              0  22.43          6.6
#
#        blood_glucose_level  diabetes  gender_Female  gender_Male  \
# 0                      140         0              1            0
# 1                       80         0              1            0
# 2                      158         0              0            1
# 3                      155         0              1            0
# 4                      155         0              0            1
# ...                    ...       ...            ...          ...
# 96708                  145         0              1            0
# 96709                   90         0              1            0
# 96710                  155         0              0            1
# 96711                  100         0              1            0
# 96712                   90         0              1            0
#
#        smoking_history_No_Info  smoking_history_current  \
# 0                            0                        0
# 1                            1                        0
# 2                            0                        0
# 3                            0                        1
# 4                            0                        1
# ...                        ...                      ...
# 96708                        1                        0
# 96709                        1                        0
# 96710                        0                        0
# 96711                        0                        0
# 96712                        0                        1
#
#        smoking_history_former  smoking_history_never  \
# 0                           0                      1
# 1                           0                      0
# 2                           0                      1
# 3                           0                      0
# 4                           0                      0
# ...                       ...                    ...
# 96708                       0                      0
# 96709                       0                      0
# 96710                       1                      0
# 96711                       0                      1
# 96712                       0                      0
#
#        smoking_history_occasional
# 0                               0
# 1                               0
# 2                               0
# 3                               0
# 4                               0
# ...                           ...
# 96708                           0
# 96709                           0
# 96710                           0
# 96711                           0
# 96712                           0
#
# [96695 rows x 14 columns]

# %%
diabetes_data_encoded_df.to_csv('diabetes.csv', index=False)
